# %%
from google.cloud import bigquery
import pandas as pd

# %%
client = bigquery.Client(location=" europe-west2")
print("Client creating using default project: {}".format(client.project))
query = """
SELECT SPECIES, ISLAND, culmen_length_mm, culmen_depth_mm, flipper_length_mm, body_mass_g, sex
FROM `ons-ids-analysis-uat.uat_wip_notebook.penguins`
"""
query_job = client.query(
query,
# Location must match that of the dataset(s) referenced in the query.
location="europe-west2",
) # API request - starts the query

all_metrics = query_job.to_dataframe()
all_metrics
# Out:
# Client creating using default project: ons-ids-analysis-uat
#                                        SPECIES  ISLAND  culmen_length_mm  \
# 0            Gentoo penguin (Pygoscelis papua)  Biscoe               NaN
# 1            Gentoo penguin (Pygoscelis papua)  Biscoe              47.3
# 2            Gentoo penguin (Pygoscelis papua)  Biscoe              44.5
# 3            Gentoo penguin (Pygoscelis papua)  Biscoe              46.2
# 4            Gentoo penguin (Pygoscelis papua)  Biscoe              44.5
# ..                                         ...     ...               ...
# 339  Chinstrap penguin (Pygoscelis antarctica)   Dream              50.2
# 340  Chinstrap penguin (Pygoscelis antarctica)   Dream              45.2
# 341  Chinstrap penguin (Pygoscelis antarctica)   Dream              46.4
# 342  Chinstrap penguin (Pygoscelis antarctica)   Dream              47.5
# 343  Chinstrap penguin (Pygoscelis antarctica)   Dream              48.1
#
#      culmen_depth_mm  flipper_length_mm  body_mass_g     sex
# 0                NaN                NaN          NaN    None
# 1               13.8              216.0       4725.0    None
# 2               14.3              216.0       4100.0    None
# 3               14.4              214.0       4650.0    None
# 4               15.7              217.0       4875.0       .
# ..               ...                ...          ...     ...
# 339             18.7              198.0       3775.0  FEMALE
# 340             16.6              191.0       3250.0  FEMALE
# 341             17.8              191.0       3700.0  FEMALE
# 342             16.8              199.0       3900.0  FEMALE
# 343             16.4              199.0       3325.0  FEMALE
#
# [344 rows x 7 columns]
